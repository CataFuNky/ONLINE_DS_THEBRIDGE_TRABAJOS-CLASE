# %% [markdown]
# "En un lugar de la Mancha"
# "Veinte años despues delante del peloton de fusilamiento"

# %% [markdown]
# 1. Primer elemento
# 2. Segundo elemento

# %% [markdown]
# * Elemento 1
# * Elemento 2
# * Elemento 3
# * Elemento 4

# %% [markdown]
# ```Python
# variable = "esto es una variable"

# %% [markdown]
# ***
# ---

# %% [markdown]
# ## Links y enlaces
# para `crear enlaces externos` a paginas web se usa `[enlace](web)`
# [enlace a google](https://www.google.es)
# Tambien podemos definir [un_enlace][mi_web].
# a una [web][mi_web] a la que podemos refenciar mas adelante
# [mi_web]: https://www.google.es

# %% [markdown]
# ![imagen en el mismo directiorio](./error.png)

# %% [markdown]
# ![imagen que no esta en el mismo directorio](./img/error.png)

# %% [markdown]
# <img src="./img/error.png" width = 80>

# %% [markdown]
# [Enlace1](https://markdownguide.org/basic-syntax)
# [Enlace2](https://daringfireball.net/project/markdown/syntax)
# [enlace3](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd)
